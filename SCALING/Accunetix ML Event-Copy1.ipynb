# %% [markdown]
# # <center align> ML Event

# %% [markdown]
# ***

# %% [markdown]
# ## Problem Statement
#
# Mr. Shaw wants to open his Luxury Car Brand BMW in one of the cities of the state of Tennessee. <br>
# He must decide if it is profitable to open his Car Brand branch in the city of Nashville. <br>
# If it is not profitable then the Branch must not be opened in the city.
#
# Using the given data Mr. Shaw must decide the fate of his Branch.

# %% [markdown]
# ***

# %% [markdown]
# ## Answer Format
#
# 1) State if Branch must opened or not <br>
# 2) State reason for your answer

# %% [markdown]
# ***

# %% [markdown]
# ### Given Data:
#
# <b> The Income of all people in the city of Nashville is given here and using the same, solution must be derived

# %% [markdown]
# ***

# %% [markdown]
# ## Procedure:
#
# 1) Extract the data <br>
# 2) Perform Visualizations  <br>
# 3) State your Answer with reason

# %% [markdown]
# ***

# %% [markdown]
# ## Solution

# %% [markdown]
# ***

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from scipy import stats

# %%
# %matplotlib inline

# %%
#%matplotlib notebook

# %% [markdown]
# ### Creating Dataframe to read contents of CVS File

# %%
df = pd.read_csv('Scaling_Better.csv')

# %%
df
# Out:
#      Income  Population
# 0        25          11
# 1        45          16
# 2        35          13
# 3        98          35
# 4        12           6
# ..      ...         ...
# 144       3           3
# 145       1           1
# 146    5846          79
# 147     421          58
# 148   98794          16
#
# [149 rows x 2 columns]

# %% [markdown]
# #### Storing the Values in Variables

# %%
income = df['Income']
print('Income')
print(income)

print()

population = df['Population']
print('Population')
print(population)
# Out:
# Income
# 0         25
# 1         45
# 2         35
# 3         98
# 4         12
#        ...
# 144        3
# 145        1
# 146     5846
# 147      421
# 148    98794
# Name: Income, Length: 149, dtype: int64
#
# Population
# 0      11
# 1      16
# 2      13
# 3      35
# 4       6
#        ..
# 144     3
# 145     1
# 146    79
# 147    58
# 148    16
# Name: Population, Length: 149, dtype: int64

# %%
df.isnull().sum()
# Out:
# Income        0
# Population    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Income      149 non-null    int64
#  1   Population  149 non-null    int64
# dtypes: int64(2)
# memory usage: 2.5 KB

# %%
income_unique = df['Income'].unique()

income_unique
# Out:
# array([        25,         45,         35,         98,         12,
#                78,         89,         56,          2,          3,
#                 1,          5,         65,          4,          8,
#                 6,         23,         79,        213, 2316645800,
#               123,        185,      96846,         13,        876,
#                21,        324,        687,        132,        684,
#             74964,         16,         30,        301,         31,
#                54,         32,        546,        874,         94,
#                 9,      65465,        312,         64,       9874,
#               654,        486,        210,        314,        798,
#               416,         20,        321,       8496,      96541,
#               231,       9651,         84,         96,         97,
#               987,       8945,         14,        974,         61,
#              5464,       8498,         10,        648,        964,
# ...

# %%
population_unique = df['Population'].unique()

population_unique
# Out:
# array([11, 16, 13, 35,  6, 25, 30, 18,  2,  1,  3, 20, 36,  4, 26, 49, 29,
#        42, 45, 70, 55, 79, 43, 63, 21,  7, 54, 19,  5, 60, 71, 87, 40, 59,
#        53, 47, 67, 58,  9, 82, 48, 86, 28, 38, 76, 83, 46, 64, 62, 17, 75],
#       dtype=int64)

# %%
df.describe()
# Out:
#              Income  Population
# count  1.490000e+02  149.000000
# mean   1.555183e+07   27.261745
# std    1.897867e+08   26.573558
# min    1.000000e+00    1.000000
# 25%    6.000000e+00    4.000000
# 50%    5.400000e+01   16.000000
# 75%    3.210000e+02   49.000000
# max    2.316646e+09   87.000000

# %%
print("MAX : \n", df.max())
print()
print("MEAN : \n", df.mean())
print()
print("MIN : \n", df.min())
# Out:
# MAX :
#  Income        2316645800
# Population            87
# dtype: int64
#
# MEAN :
#  Income        1.555183e+07
# Population    2.726174e+01
# dtype: float64
#
# MIN :
#  Income        1
# Population    1
# dtype: int64

# %%
np.median(df['Income'])
# Out:
# 54.0

# %%
stats.mode(df['Income'])
# Out:
# ModeResult(mode=array([1], dtype=int64), count=array([17]))

# %% [markdown]
# ### Using Visualizations

# %%
fig = plt.figure()
fig.set_figwidth(20)
fig.set_figheight(5)

sns.barplot(x = population, y = income)
# Out:
# <AxesSubplot:xlabel='Population', ylabel='Income'>

# %%
fig = plt.figure()
fig.set_figwidth(70)
fig.set_figheight(26)

sns.barplot(x = income, y = population)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='Population'>

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# %%
income.values.reshape(-1,1)
# Out:
# array([[        25],
#        [        45],
#        [        35],
#        [        98],
#        [        12],
#        [        45],
#        [        78],
#        [        89],
#        [        56],
#        [         2],
#        [         3],
#        [         1],
#        [         2],
#        [         5],
#        [        65],
#        [        45],
#        [        98],
#        [        12],
#        [        35],
#        [         4],
#        [         8],
#        [         6],
#        [         1],
#        [        23],
#        [        45],
#        [        78],
#        [        79],
#        [       213],
#        [         3],
#        [         4],
#        [        89],
#        [        45],
#        [         1],
#        [2316645800],
#        [         4],
#        [       123],
#        [       185],
#        [         4],
#        [     96846],
#        [        13],
#        [       213],
#        [       876],
#        [        13],
# ...

# %%
income_standard_scaler = scaler.fit_transform(df['Income'].values[Ellipsis, None])

population_standard_scaler = scaler.fit_transform(df['Population'].values[Ellipsis, None])

# %%
income_flat = income_standard_scaler.flatten()

population_flat = population_standard_scaler.flatten()

# %%
income_flat
# Out:
# array([-0.08221999, -0.08221988, -0.08221993, -0.0822196 , -0.08222006,
#        -0.08221988, -0.08221971, -0.08221965, -0.08221982, -0.08222011,
#        -0.0822201 , -0.08222011, -0.08222011, -0.08222009, -0.08221978,
#        -0.08221988, -0.0822196 , -0.08222006, -0.08221993, -0.0822201 ,
#        -0.08222008, -0.08222009, -0.08222011, -0.08222   , -0.08221988,
#        -0.08221971, -0.0822197 , -0.08221899, -0.0822201 , -0.0822201 ,
#        -0.08221965, -0.08221988, -0.08222011, 12.16552501, -0.0822201 ,
#        -0.08221947, -0.08221914, -0.0822201 , -0.08170811, -0.08222005,
#        -0.08221899, -0.08221549, -0.08222005, -0.08222001, -0.08221841,
#        -0.08221649, -0.08222009, -0.08221942, -0.0822201 , -0.08222011,
#        -0.0822165 , -0.0822196 , -0.0818238 , -0.08222003, -0.08222011,
#        -0.08221996, -0.08221853, -0.08221996, -0.08222009, -0.08221983,
#        -0.08222009, -0.08221995, -0.08221996, -0.08221723, -0.0822155 ,
# ...

# %%
population_flat
# Out:
# array([-0.61401603, -0.42522447, -0.53849941,  0.29218344, -0.80280759,
#        -0.42522447, -0.08539967,  0.10339189, -0.34970785, -0.95384084,
#        -0.95384084, -0.99159915, -0.95384084, -0.91608252, -0.27419123,
#        -0.42522447,  0.32994176, -0.80280759, -0.53849941, -0.91608252,
#        -0.87832421, -0.91608252, -0.99159915, -0.04764136, -0.42522447,
#        -0.08539967, -0.08539967,  0.8207998 , -0.95384084, -0.91608252,
#         0.06563358, -0.42522447, -0.99159915, -0.80280759, -0.91608252,
#         0.55649162,  0.66976656, -0.91608252, -0.42522447, -0.80280759,
#         0.8207998 ,  1.61372435, -0.80280759, -0.61401603,  1.04734967,
#         1.95354915, -0.87832421,  0.59424994, -0.95384084, -0.99159915,
#         1.34941617,  0.32994176, -0.23643292, -0.76504928, -0.99159915,
#        -0.53849941,  1.00959136, -0.53849941, -0.87832421, -0.31194954,
#        -0.8405659 , -0.53849941, -0.53849941,  1.23614123,  1.65148266,
# ...

# %%
population_flat.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\Public\Documents\iSkysoft\CreatorTemp/ipykernel_692/3219752664.py in <module>
# ----> 1 population_flat.describe()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'describe'

# %%
print("MAX : \n", population_flat.max())
print()
print("MEAN : \n", population_flat.mean())
print()
print("MIN : \n", population_flat.min())
# Out:
# MAX :
#  2.25561564128952
#
# MEAN :
#  -4.7687431930208065e-17
#
# MIN :
#  -0.991599146653847

# %%
fig = plt.figure()
fig.set_figwidth(120)
fig.set_figheight(100)

sns.barplot(x = population_flat, y = income_flat)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Logarithm Scaling

# %%
income_log = np.log1p(income)

population_log = np.log1p(population)

# %%
print(income, income_log)
# Out:
# 0         25
# 1         45
# 2         35
# 3         98
# 4         12
#        ...
# 144        3
# 145        1
# 146     5846
# 147      421
# 148    98794
# Name: Income, Length: 149, dtype: int64 0       3.258097
# 1       3.828641
# 2       3.583519
# 3       4.595120
# 4       2.564949
#          ...
# 144     1.386294
# 145     0.693147
# 146     8.673684
# 147     6.045005
# 148    11.500802
# Name: Income, Length: 149, dtype: float64

# %%
fig = plt.figure()
fig.set_figwidth(120)
fig.set_figheight(100)

sns.barplot(x = population_log, y = income_log)
# Out:
# <AxesSubplot:xlabel='Population', ylabel='Income'>
